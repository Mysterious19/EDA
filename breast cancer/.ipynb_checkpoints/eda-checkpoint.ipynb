# %%
#Loading libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import norm
import seaborn as sns

# %%
#loading dataset
data = pd.read_csv('data 2.csv',index_col=False)
data.drop('Unnamed: 32',axis=1,inplace=True)
data.drop('id',axis=1,inplace=True)

# %%
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
#basic descriptive stats
data.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
data.skew()
# Out:
# radius_mean                0.942380
# texture_mean               0.650450
# perimeter_mean             0.990650
# area_mean                  1.645732
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               5.110463
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# compactness_worst          1.473555
# ...

# %%
data.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
#group by diagnosis and review the output
dia_grp = data.groupby('diagnosis',axis=0)
pd.DataFrame(dia_grp.size(),columns=['# of observations'])
# Out:
#            # of observations
# diagnosis
# B                        357
# M                        212

# %%
#Unimodal Data Visualisations

#sns.set_style("white")
#sns.set_context({"figure.figsize":(10,8)})
sns.countplot(data['diagnosis'],label='Count')

# %%
data_mean = data.ix[:,1:11]
data_se = data.ix[:,11:21]
data_worst = data.ix[:,21:]

# %%
#Histograms 
hist_mean = data_mean.hist(bins=10,grid=False)

# %%
hist_se = data_se.hist(bins=10,grid=False)

# %%
hist_worst = data_worst.hist(bins=10,grid=False)

# %%
#density plots
plt = data_mean.plot(kind='density',subplots='True',layout=(4,3),sharex=False,sharey=False,figsize=(15,10))

# %%
plt = data_se.plot(kind='density',subplots=True,sharex=False,sharey=False,layout=(4,3),figsize=(15,10))

# %%
plt = data_worst.plot(kind='density',subplots=True,layout=(4,3),sharex=False,sharey=False,figsize=(15,10))

# %%
#Boxplots
plt=data_mean.plot(kind= 'box' , subplots=True, layout=(4,4), sharex=False, sharey=False,fontsize=12,figsize=(15,10))

# %%
#plt=data_se.plot(kind= 'box' , subplots=True, layout=(4,4), sharex=False, sharey=False,fontsize=12)

#plt=data_worst.plot(kind= 'box' , subplots=True, layout=(4,4), sharex=False, sharey=False,fontsize=12)
